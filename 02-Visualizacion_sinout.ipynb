# %% [markdown]
# # VISUALIZACION
# ---

# %%
import pandas as pd
import numpy as np
import sidetable
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import re
plt.rcParams["figure.figsize"] = (10,8)
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("datos/02-bikes_sinoutliers.csv", index_col= 0).reset_index(drop= True)
df.head()
# Out:
#    season  yr  mnth  holiday  weekday  workingday  weathersit       temp  \
# 0  winter   0     1        1        1           0           2  14.110847
# 1  winter   0     2        0        4           1           2  14.902598
# 2  winter   0     3        0        4           1           1   8.050924
# 3  spring   0     4        0        7           0           1   8.200000
# 4  spring   0     5        0        2           1           1   9.305237
#
#       atemp      hum  windspeed  registered
# 0  18.18125  80.5833  10.749882         654
# 1  17.68695  69.6087  16.652113         670
# 2   9.47025  43.7273  16.636703        1229
# 3  10.60610  59.0435  10.739832        1454
# 4  11.46350  43.6957  12.522300        1518

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 716 entries, 0 to 715
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      716 non-null    object
#  1   yr          716 non-null    int64
#  2   mnth        716 non-null    int64
#  3   holiday     716 non-null    int64
#  4   weekday     716 non-null    int64
#  5   workingday  716 non-null    int64
#  6   weathersit  716 non-null    int64
#  7   temp        716 non-null    float64
#  8   atemp       716 non-null    float64
#  9   hum         716 non-null    float64
#  10  windspeed   716 non-null    float64
#  11  registered  716 non-null    int64
# dtypes: float64(4), int64(7), object(1)
# memory usage: 67.2+ KB

# %%
# Volvemos a cambiar a category algunas columnas ya que se modifican al guardar y cargar
df[["yr", "mnth", "holiday", "weekday", "workingday", "weathersit"]] = df[["yr", "mnth", "holiday", "weekday", "workingday", "weathersit"]].astype("category")

# %% [markdown]
# ### Distribución variable *Registered*

# %%
sns.histplot(data = df, x = "registered");

# %% [markdown]
# ### Correlación

# %%
masc = np.triu(np.ones_like(df.corr(), dtype=np.bool_))

# %%
sns.heatmap(df.corr(), mask= masc, annot= True);

# %% [markdown]
# Podemos observar que se puede eliminar la columna temp o atemp, una de las 2

# %% [markdown]
# ### Variables numéricas

# %%
# Hacemos una lista con las columnas que queremos comparar con la columna "registered"
lista_columnas = ["temp", "atemp", "hum", "windspeed"]

# %%
# Hacemos un regplot para compararlas con registered
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (15, 10))
axes = axes.flat

for i, colum in enumerate(lista_columnas):
    sns.regplot(
        x = df[colum],
        y = df["registered"],
        color = "black",
        marker = ".",
        scatter_kws = {"alpha": 0.4},
        line_kws = {"color": "red", "alpha": 0.7 },
        ax = axes[i])
    axes[i].set_title(f"Registered vs {colum}")
    axes[i].set_xlabel("")
    axes[i].set_ylabel("")
fig.tight_layout();

# %%
#Gráfico de distribución para cada variable numérica

fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (15, 10))

axes = axes.flat

for i, colum in enumerate(lista_columnas): 
    sns.histplot(
        data = df,
        x = colum,
        kde = True,
        ax = axes[i])
    
    axes[i].set_title(colum)
    axes[i].tick_params()
    axes[i].set_xlabel("")
    axes[i].set_ylabel( "count")

fig.tight_layout();

# %% [markdown]
# ### Variables categóricas

# %%
fig, axes = plt.subplots(nrows = 4, ncols = 2, figsize = (20, 30))

axes = axes.flat

columnas_cat = df.select_dtypes(include =['category','object']).columns

for i, colum in enumerate(columnas_cat): 
    sns.countplot(
        data = df,
        x = colum,
        color = "skyblue",
        ax = axes[i])
    
    axes[i].set_title(colum, fontsize = 25)
    axes[i].tick_params()
    axes[i].set_xlabel("")
    axes[i].set_ylabel( "count")

fig.tight_layout();

# %% [markdown]
# ### Variables categóricas con **registered**

# %%
df_hol = df.groupby("holiday").sum().reset_index()

# %%
ax = sns.barplot(x= "holiday", y = "registered", data = df_hol, errwidth=0)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '2.55162e+06'), Text(0, 0, '82228')]

# %%
df.groupby("holiday")["registered"].sum()
# Out:
# holiday
# 0    2551623
# 1      82228
# Name: registered, dtype: int64

# %%
df_work = df.groupby("workingday").sum().reset_index()
ax = sns.barplot(x= "workingday", y = "registered", data = df_work, errwidth=0)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '816033'), Text(0, 0, '1.81782e+06')]

# %%
df_week = df.groupby("weekday").sum().reset_index()
ax = sns.barplot(x= "weekday", y = "registered", data = df_week, errwidth=0)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '323985'),
#  Text(0, 0, '360677'),
#  Text(0, 0, '379438'),
#  Text(0, 0, '410572'),
#  Text(0, 0, '402945'),
#  Text(0, 0, '396449'),
#  Text(0, 0, '359785')]

# %%
df_season = df.groupby("season").sum().reset_index()
ax = sns.barplot(x= "season", y = "registered", data = df_season, errwidth=0)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '676081'),
#  Text(0, 0, '685929'),
#  Text(0, 0, '775752'),
#  Text(0, 0, '496089')]

# %%
df_month = df.groupby("mnth").sum().reset_index()
ax = sns.barplot(x= "mnth", y = "registered", data = df_month, errwidth=0)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '158894'),
#  Text(0, 0, '160207'),
#  Text(0, 0, '206799'),
#  Text(0, 0, '216910'),
#  Text(0, 0, '242208'),
#  Text(0, 0, '253636'),
#  Text(0, 0, '252535'),
#  Text(0, 0, '251229'),
#  Text(0, 0, '258564'),
#  Text(0, 0, '237225'),
#  Text(0, 0, '210748'),
#  Text(0, 0, '184896')]

# %%
df_weather = df.groupby("weathersit").sum().reset_index()
ax = sns.barplot(x= "weathersit", y = "registered", data = df_weather, errwidth=0)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '1.78435e+06'), Text(0, 0, '816102'), Text(0, 0, '33397')]

# %%
df_yr = df.groupby("yr").sum().reset_index()
ax = sns.barplot(x= "yr", y = "registered", data = df_yr, errwidth=0)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '984733'), Text(0, 0, '1.64912e+06')]

# %%
df.head()
# Out:
#    season yr mnth holiday weekday workingday weathersit       temp     atemp  \
# 0  winter  0    1       1       1          0          2  14.110847  18.18125
# 1  winter  0    2       0       4          1          2  14.902598  17.68695
# 2  winter  0    3       0       4          1          1   8.050924   9.47025
# 3  spring  0    4       0       7          0          1   8.200000  10.60610
# 4  spring  0    5       0       2          1          1   9.305237  11.46350
#
#        hum  windspeed  registered
# 0  80.5833  10.749882         654
# 1  69.6087  16.652113         670
# 2  43.7273  16.636703        1229
# 3  59.0435  10.739832        1454
# 4  43.6957  12.522300        1518

# %% [markdown]
# Eliminamos las columnas **dteday**, porque lo que nos aporta se refleja en otras columnas, **temp**, porque su información es redundante con *atemp*, y **cnt** y **casual** porque hemos decidido quedarnos con *registered*

# %%
df.head(2)
# Out:
#    season yr mnth holiday weekday workingday weathersit       temp     atemp  \
# 0  winter  0    1       1       1          0          2  14.110847  18.18125
# 1  winter  0    2       0       4          1          2  14.902598  17.68695
#
#        hum  windspeed  registered
# 0  80.5833  10.749882         654
# 1  69.6087  16.652113         670
